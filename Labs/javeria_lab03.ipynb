# %%
# !pip install -U google-genai

from google import genai


MODEL = "models/gemini-3.6-flash"

client = genai.Client(api_key="")

def travel_agent(user_input):

    prompt = f"""
You are a professional travel agent for Pakistan tourism.

Provide a well-structured travel plan with clear headings:

1. Destination Overview
2. Budget Travel Options (Bus, Train, Flight with approx cost in PKR)
3. Places to Visit (specific locations)
4. Food Suggestions (local dishes)
5. Money-Saving Tips

Make response detailed but easy for students.

User request: {user_input}

Travel Plan:
"""


    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Travel Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.13/dist-packages (2.22.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (4.14.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in /usr/local/lib/python3.13/dist-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.57.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in /usr/local/lib/python3.13/dist-packages (from google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.13/dist-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.19)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (50.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.13/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.6.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (3.0)
# Gemini Travel Agent Started (type 'exit' to stop)
#
# You: hello
#
# Agent:
#  Assalam-o-Alaikum! Welcome to your official guide to exploring Pakistan.
#
# Since you haven't specified a destination yet, I have prepared a comprehensive, student-friendly travel plan for **Hunza Valley**—the ultimate dream destination for students, offering breathtaking landscapes, safety, rich culture, and affordability.
#
# Here is your complete travel blueprint:
#
# ---
#
# # 🏔️ Destination Overview: Hunza Valley (Gilgit-Baltistan)
#
# Located in the northern region of Pakistan, Hunza Valley is world-famous for its dramatic snow-capped peaks (including Rakaposhi), turquoise lakes, centuries-old forts, and incredibly welcoming locals. It is one of the safest and most picturesque places in the country, making it the perfect getaway for student groups looking for adventure without breaking the bank.
#
# * **Best Time to Visit:** May to October (pleasant weather) or October to November (Autumn colors).
# * **Ideal Trip Duration:** 5 to 7 Days.
#
# ---
#
# # 🚌 Budget Travel Options (Islamabad to Hunza)
#
# *Note: Prices are approximate return/one-way estimates per person in PKR and subject to seasonal changes.*
#
# ### 1. By Bus (Most Recommended for Students)
# * **Services:** NATCO, Faisal Movers, or Silk Line (Islamabad to Aliabad/Karimabad).
# * **Cost:** PKR 4,500 – 6,500 (one-way).
# * **Travel Time:** 16 to 18 hours via the Karakoram Highway (KKH) or Babusar Top (in summer).
#
# ### 2. By Train + Bus (For Students Traveling from Karachi/Lahore)
# * **Train:** Travel from Karachi/Lahore to Rawalpindi via Tezgam or Awam Express (Economy Class: PKR 2,000 – 3,500 one-way).
# * **Bus:** From Rawalpindi/Islamabad, take a local bus to Hunza (PKR 4,500 - 6,500).
# * **Total Estimated Travel Cost:** PKR 12,000 – 18,000 (round trip).
#
# ### 3. By Flight (Fastest, High Budget)
# * **Route:** PIA Flight from Islamabad to Gilgit Airport (1 hour), followed by a 2-hour taxi/HiAce drive to Hunza.
# * **Cost:** PKR 25,000 – 45,000 (one-way flight) + PKR 1,500 (shared transport to Hunza).
# * *Note: Flights are highly subject to weather conditions.*
#
# ---
#
# # 📍 Places to Visit
#
# 1. **Karimabad Bazaar & Historic Forts:**
#    * **Baltit Fort & Altit Fort:** 800-year-old heritage sites offering rich history and incredible valley views.
# 2. **Attabad Lake:**
#    * A stunning turquoise lake created by a landslide in 2010. Perfect for group jet-skiing and motorboating.
# 3. **Passu Cones & Hussaini Suspension Bridge:**
#    * Iconic needle-like mountain peaks and one of the world's most thrilling walking suspension bridges.
# 4. **Eagle's Nest (Duikar):**
#    * The highest viewpoint in Hunza—famous for watching dramatic golden sunsets over the Karakoram range.
# 5. **Khunjerab Pass (Pak-China Border):**
#    * The highest paved border crossing in the world (15,397 ft). Don't forget to take photos with the world's highest ATM!
#
# ---
#
# # 🍲 Local Food Suggestions
#
# Hunza cuisine is healthy, mild, and delicious. Be sure to try:
#
# * **Chapshuro:** Often called the "Hunza Pizza"—a warm flatbread stuffed with seasoned minced meat, onions, and local herbs. (Approx. PKR 300–500).
# * **Gyal:** Soft pancake-like bread served with apricot oil or local honey.
# * **Hoilo Garma:** A hearty local pasta dish cooked with spinach and traditional dried cheese (Qurut).
# * **Tumuru Tea:** A fragrant local herbal tea made from wild mountain thyme—great for cold evenings.
# * **Apricot Cake:** Available at famous local bakeries in Karimabad.
#
# ---
#
# # 💡 Money-Saving Tips for Students
#
# 1. **Travel in Groups (4–6 Friends):** Splitting hotel room costs, jeeps, and food bills significantly drops your per-person expense.
# 2. **Use Shared Local Vans (HiAce):** Avoid hiring private Prados/Jeeps for long distances. Use local shared transport between Gilgit, Aliabad, Karimabad, and Passu.
# 3. **Stay in Campsites or Homestays:** Instead of luxury resorts, opt for budget guest houses in Karimabad or tent camping at Attabad Lake (PKR 1,500 – 3,000 per night for a group).
# 4. **Carry Student IDs:** You can often get discounted entry fees at historical sites like Baltit and Altit Forts.
# 5. **Eat at Local Dhabas:** High-end tourist restaurants can be expensive. Eat at small local eateries where the food is authentic, fresh, and half the price.
#
# ---
#
# *If you have a specific city of origin, a set budget, or another destination in mind (like Skardu, Swat, or Neelum Valley), feel free to let me know, and I can tailor an exact day-wise itinerary for you!*
#
# You: I'm in karachi and want to travel lahore with 30000 PKR
#
# Agent:
#  Welcome! As your Pakistan Tourism Travel Agent, I’ve put together an exciting, budget-friendly, step-by-step travel plan for your trip from **Karachi to Lahore**.
#
# With a budget of **PKR 30,000**, you can easily enjoy a memorable **4-Day / 3-Night trip** to the cultural heart of Pakistan.
#
# ---
#
# ### 1. Destination Overview
# Lahore, often called the *"Heart of Pakistan,"* is a vibrant city known for its rich Mughal architecture, bustling bazaars, warm hospitality, and legendary food culture. For students, it is an ideal destination: affordable, easy to navigate using public transport, and packed with historic sights and lively hangouts.
#
# ---
#
# ### 2. Budget Travel Options (Karachi ⇄ Lahore Return)
#
# To keep within your PKR 30,000 total budget, your transportation choice is key. Here are your options:
#
# *   **Train (Most Recommended for Students):**
#     *   **Economy Class (Pak Business Express / Tezgam):** ~PKR 2,600 – PKR 3,200 (One-Way) | **Return: ~PKR 5,500 - 6,500** *(Best budget option)*
#     *   **AC Standard / Business Class (Green Line / Karakoram):** ~PKR 6,500 – PKR 8,500 (One-Way) | **Return: ~PKR 13,000 - 17,000** *(Comfortable & affordable)*
# *   **Bus (Faisal Movers / Daewoo Express / Road Master):**
#     *   **Executive / Standard Sleeper:** ~PKR 4,800 – PKR 6,500 (One-Way) | **Return: ~PKR 10,000 - 13,000**
# *   **Flight (PIA / Airblue / Fly Jinnah):**
#     *   ~PKR 18,000 – PKR 25,000 (One-Way) | **Return: ~PKR 36,000 - 50,000** *(Exceeds your budget)*
#
# 💡 **Agent Recommendation:** Book **Economy Class (Return ~PKR 6,000)** or **AC Standard Train (Return ~PKR 13,000)** to leave plenty of room for food, local transport, and accommodation.
#
# ---
#
# ### 3. Places to Visit (Specific Locations)
#
# Here is a simple 4-day itinerary tailored for students:
#
# *   **Day 1: Historical Heart (Walled City)**
#     *   **Badshahi Mosque:** Iconic Mughal architecture.
#     *   **Lahore Fort (Shahi Qila) & Sheesh Mahal:** Explore ancient palaces and grounds.
#     *   **Minar-e-Pakistan & Greater Iqbal Park:** Right next to Badshahi Mosque.
# *   **Day 2: Heritage & Culture**
#     *   **Shalimar Gardens:** Grand Mughal gardens.
#     *   **Tomb of Jahangir & Asif Khan:** Quiet, scenic historical complex across the Ravi river.
#     *   **Anarkali Bazaar:** Great for budget shopping and vibrant street vibes.
# *   **Day 3: Museums & Modern Lahore**
#     *   **Lahore Museum:** One of the best museums in South Asia (displaying ancient Gandhara art).
#     *   **Army Museum Lahore:** Modern, highly interactive museum (very popular among young visitors).
#     *   **Liberty Market & MM Alam Road:** Walk around modern shopping hubs in Gulberg.
# *   **Day 4: Old City Gates & Shopping**
#     *   **Delhi Gate & Shahi Hammam (Royal Bathhouse):** Restored historical architecture.
#     *   **Wazir Khan Mosque:** Famous for its stunning tile work (Kashi-kari).
#
# ---
#
# ### 4. Food Suggestions (Local Dishes & Spots)
#
# Lahore is famous for its food! Here is what you must try on a student budget:
#
# *   **Breakfast:**
#     *   **Halwa Puri & Chana:** Try *Sadiq Halwa Puri* or local spots around Railway Station / Gawalmandi (~PKR 200–300 per person).
# *   **Lunch / Dinner:**
#     *   **Chicken/Mutton Karahi:** *Butt Karahi* (Lakshmi Chowk) or *Dhamthal/Fiqah* (~PKR 800–1,200 per head shared).
#     *   **Siri Paye / Nihari:** *Waris Nihari* or *Phajja Paye* in Old City (~PKR 500–700).
#     *   **Tawa Fish & BBQ:** *Beshiram Tawa Fish* or street food stalls at Mozang (~PKR 500–800).
# *   **Snacks & Desserts:**
#     *   **Nan Khatai:** Grab a box from *Khalifa Bakers* inside Delhi Gate (Great souvenir to take back to Karachi!).
#     *   **Falooda & Cup Ice Cream:** *Chaman Ice Cream* on Mall Road or *Riaz Falooda*.
#
# ---
#
# ### 5. Money-Saving Tips (Student Edition)
#
# 1.  **Use Public Transit (Metro & Speedo Buses):**
#     *   Instead of taking cabs everywhere, use the **Lahore Metro Bus** and **Orange Line Metro Train**. Tickets cost only **PKR 30 per trip** and cover almost all major sights along Mall Road and North Lahore.
# 2.  **Bring Your Student ID:**
#     *   Carry your original university/college ID card. You can get heavily discounted entry tickets at places like Lahore Fort, Museums, and Parks.
# 3.  **Share Accommodation:**
#     *   Book a budget hotel or guest house near **Mall Road, Davis Road, or Lakshmi Chowk** (rates: PKR 1,500 – 2,500 per night). If traveling with 1–2 friends, splitting a room brings accommodation costs down to ~PKR 1,000/night per person.
# 4.  **Use Bike-Hailing Apps:**
#     *   For short routes where public transport isn't available, use **Yango, InDrive, or Bykea (Bike option)**—it costs a fraction of a rickshaw or regular taxi ride.
# 5.  **Pre-Book Train Tickets:**
#     *   Book train tickets via the *Pak Railways app* at least 1–2 weeks in advance to secure Economy/AC seats without paying extra booking agent fees.
#
# ---
#
# ### 💰 Estimated Trip Budget Breakdown (Per Person)
#
# | Expense | Estimated Cost (PKR) |
# | :--- | :--- |
# | **Return Train (AC Standard/Economy)** | 8,000 – 12,000 |
# | **Accommodation (3 Nights Shared)** | 4,000 – 6,000 |
# | **Food & Snacks (4 Days)** | 6,000 – 7,000 |
# | **Local Transport (Metro/Bike Apps)** | 1,500 – 2,000 |
# | **Entry Tickets & Shopping Buffer** | 2,000 – 3,000 |
# | **TOTAL ESTIMATED COST** | **PKR 21,500 – 30,000** |
#
# *Have a safe trip and enjoy your time exploring Lahore! Feel free to ask if you need hotel contacts or customized daily schedules.*
#
# You: bye
#
# Agent:
#  Welcome! As your Pakistan Tourism guide, I have put together a complete, budget-friendly student travel plan for **Hunza Valley**—one of the most breathtaking, safe, and popular destinations in Northern Pakistan.
#
# ---
#
# ### 1. Destination Overview
# **Hunza Valley** is located in the Gilgit-Baltistan region of Pakistan. Surrounded by majestic snow-capped peaks like Rakaposhi and Ladyfinger, Hunza offers world-class landscapes, crystal-clear blue lakes, rich mountain culture, and high safety standards. It is an ideal destination for students seeking adventure, stunning photography spots, and peaceful mountain retreats without breaking the bank.
#
# ---
#
# ### 2. Budget Travel Options (From Islamabad Hub)
#
# *Prices are estimated per person for one-way travel in PKR:*
#
# * **Bus (Most Recommended for Students):**
#   * **NATCO, Faisal Movers, or Daewoo Express:** Direct coaster/bus from Rawalpindi/Islamabad to Aliabad (Hunza) via the Karakoram Highway (KKH).
#   * **Cost:** PKR 4,500 – PKR 6,500 (one-way)
#   * **Travel Time:** ~16 to 18 hours
#
# * **Train + Bus Combo (For students coming from Karachi/Lahore):**
#   * **Train:** Economy class from Karachi/Lahore to Rawalpindi (Green Line / Tezgam / Tezraftar).
#   * **Cost:** PKR 2,000 – PKR 4,500 (Economy to AC Standard)
#   * **Next Step:** Switch to a local bus/hiace from Rawalpindi to Hunza.
#
# * **Flight (Fastest but Pricier):**
#   * **PIA Flight:** Islamabad (ISB) to Gilgit Airport (GIL), followed by a 2-hour shared local Hiace to Karimabad, Hunza.
#   * **Cost:** PKR 22,000 – PKR 38,000 (one-way, subject to weather and availability)
#
# * **Local Internal Transport (Within Hunza):**
#   * Shared Suzuki Carry / Hiace between towns: PKR 150 – PKR 400 per trip.
#
# ---
#
# ### 3. Places to Visit (Specific Locations)
#
# 1. **Karimabad Bazaar & Historical Forts:**
#    * **Baltit Fort & Altit Fort:** 700+ year-old historical fortresses with incredible mountain vistas.
# 2. **Eagle’s Nest (Duikar):**
#    * Highest viewpoint in Hunza; famous for sunset and sunrise views over 7,000m peaks.
# 3. **Attabad Lake:**
#    * Famous turquoise lake formed in 2010. Great for budget group boating.
# 4. **Passu Cones & Hussaini Suspension Bridge:**
#    * Iconic needle-shaped peaks and the world-famous thrilling rope bridge.
# 5. **Khunjerab Pass (Pak-China Border):**
#    * Located at 16,000 ft, featuring the world’s highest ATM and wild yak sightings.
#
# ---
#
# ### 4. Food Suggestions (Local Dishes)
#
# * **Chapshuro (Hunza Pizza):** Bread stuffed with minced meat, onions, and local spices. (Very cheap & filling: PKR 200 – 350 per piece).
# * **Gyal & Hoilo Garma:** Local wheat pancakes served with organic wild seeds and spinach pasta cooked in local apricot oil.
# * **Tumuru Tea:** A warm, aromatic local herbal tea made from wild thyme gathered in the mountains (PKR 50 – 100 per cup).
# * **Apricot Cake:** Famous dessert available at local bakeries in Karimabad Bazaar (e.g., *Cafe de Hunza*).
# * **Mamtu:** Steamed meat dumplings served with spicy chili sauce (PKR 300 – 500 per plate).
#
# ---
#
# ### 5. Money-Saving Tips for Students
#
# 1. **Travel in Groups (4–6 Friends):** Split the costs of accommodation, private jeeps, and food platters evenly.
# 2. **Carry Your Student ID Card:** Show your original student ID at heritage sites like Altit and Baltit Forts to get ticket discounts.
# 3. **Stay in Campsites or Homestays:** Skip luxury hotels; opt for local family-run homestays or set up tents at managed camping grounds (PKR 800 – 1,500 per night per head).
# 4. **Use Shared Transport:** Instead of booking a private car for the whole tour, use local shared Hiace vans running daily between Gilgit, Aliabad, Gulmit, and Passu.
# 5. **Eat Street Snacks & Local Dhaba Food:** Chapshuro and local dhabas are far cheaper and fresher than tourist-oriented restaurants.
#
# You: exit
# Goodbye

# %%
def anomaly_detection_agent(user_input):

    prompt = f"""
You are a professional anamoly detection agent for jirzo's login page.

 Notify user if user's account is login with unauthorized device:

1. Login with unauthorized device
2. username
3. login failed attempt


Make response detailed but easy for user.

User request: {user_input}

Login Alert:
"""


    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Anomaly Detection Agent (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = anomaly_detection_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# Gemini Anomaly Detection Agent (type 'exit' to stop)
#
# You: hello
#
# Agent:
#  **⚠️ Security Alert: Unauthorized Login Attempt Detected**
#
# Hello,
#
# We detected a suspicious login attempt on your **Jirzo** account from a device that has not been recognized or authorized previously.
#
# Below are the details of the detected activity:
#
# ---
#
# ### **Incident Details:**
# * **Account Username:** `[User's Username]`
# * **Event:** Login Attempt from an Unauthorized Device
# * **Failed Login Attempts:** `[Number, e.g., 3]` failed attempt(s) detected prior to this alert
# * **Device / Browser:** `[e.g., Unknown Device / Chrome on Linux]`
# * **IP Address:** `[e.g., 192.168.x.x]`
# * **Time:** `[Date and Time]`
#
# ---
#
# ### **What does this mean?**
# Someone tried to access your account using an unrecognized device, and multiple failed password attempts were logged. As a security precaution, we have temporarily blocked access from this device to protect your account data.
#
# ---
#
# ### **What should you do next?**
#
# #### 🔴 **If this was NOT you:**
# 1. **Change your password immediately:** Log in from a trusted device and update your password to a strong, unique one.
# 2. **Revoke active sessions:** Go to your **Jirzo Account Settings > Security > Active Sessions** and terminate all unknown devices.
# 3. **Enable Two-Factor Authentication (2FA):** If you haven't already, turn on 2FA for an extra layer of protection.
#
# #### 🟢 **If this WAS you:**
# If you were trying to log in from a new device or browser, please verify your identity using your primary device or approve the login via your registered email to authorize this device.
#
# ---
#
# If you need further assistance, please reach out to our Support Team immediately at **support@jirzo.com**.
#
# Stay safe,
# **Jirzo Automated Security & Anomaly Detection Team**
#
# You: i want more detail
#
# Agent:
#  **[SECURITY ALERT] Unauthorized Login Activity Detected on Your Jirzo Account**
#
# Dear User,
#
# Our automated Anomaly Detection System at **Jirzo** has flagged a suspicious login attempt on your account. Because this attempt originated from a device you have never used before and included multiple failed credentials, we have temporarily blocked the activity to keep your account safe.
#
# Here is the detailed breakdown of the detected event:
#
# ---
#
# ### **Incident Details**
#
# * **Username:** `[User's Username / Email]`
# * **Device Status:** **Unauthorized / Unrecognized Device**
# * **Failed Login Attempts:** **3 Failed Attempts** *(Incorrect password entered)*
# * **Event Severity:** High (Flagged by Security System)
#
# ---
#
# ### **Technical Breakdown (Event Details)**
#
# * **Device Info:** Unknown Device (e.g., *Linux / Firefox v118.0*)
# * **IP Address:** `192.0.2.45` *(Unrecognized Network)*
# * **Approximate Location:** `[City, Country]`
# * **Timestamp:** `YYYY-MM-DD HH:MM:SS UTC`
#
# ---
#
# ### **What Does This Mean?**
# Our system constantly monitors your login patterns (such as your typical devices, browsers, and locations). This alert was triggered because someone tried to log into your account using a **new device that isn't on your trusted list**, and they **failed to enter the correct password** multiple times.
#
# ---
#
# ### **What Should You Do Next?**
#
# #### **If this WAS YOU:**
# If you were trying to log in from a new phone, computer, or browser, you can ignore this alert. However, to stop future warnings, make sure to complete the two-factor verification prompt on your trusted device to authorize this new browser.
#
# #### **If this WAS NOT YOU (Recommended Security Steps):**
# If you did not attempt to log in at the time listed above, your account details may be at risk. Please take the following steps immediately:
#
# 1. **Reset Your Password:** Change your Jirzo password immediately to a strong, unique password.
# 2. **Revoke Active Sessions:** Go to **Account Settings > Security > Active Sessions** and click **"Log Out All Other Devices."**
# 3. **Enable Two-Factor Authentication (2FA):** If you haven't already, turn on 2FA for an extra layer of protection.
#
# ---
#
# *Need assistance? Contact the Jirzo Security Team directly at [security@jirzo.com] or reply to this message.*
#
# **Jirzo Automated Security & Anomaly Detection Team**
#
# You: exit
# Goodbye
